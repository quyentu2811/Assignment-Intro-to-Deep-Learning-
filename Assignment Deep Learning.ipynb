# %%
# !pip install torchsummary
# !pip install torchgeometry
# !pip install wandb
# Out:
# Requirement already satisfied: torchsummary in /opt/conda/lib/python3.10/site-packages (1.5.1)
# Requirement already satisfied: torchgeometry in /opt/conda/lib/python3.10/site-packages (0.1.2)
# Requirement already satisfied: torch>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from torchgeometry) (2.0.0)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch>=1.0.0->torchgeometry) (3.12.2)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from torch>=1.0.0->torchgeometry) (4.5.0)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=1.0.0->torchgeometry) (1.12)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=1.0.0->torchgeometry) (3.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=1.0.0->torchgeometry) (3.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=1.0.0->torchgeometry) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=1.0.0->torchgeometry) (1.3.0)
# Requirement already satisfied: wandb in /opt/conda/lib/python3.10/site-packages (0.16.0)
# Requirement already satisfied: Click!=8.0.0,>=7.1 in /opt/conda/lib/python3.10/site-packages (from wandb) (8.1.7)
# Requirement already satisfied: GitPython!=3.1.29,>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (3.1.32)
# Requirement already satisfied: requests<3,>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (2.31.0)
# Requirement already satisfied: psutil>=5.0.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (5.9.3)
# Requirement already satisfied: sentry-sdk>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (1.34.0)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (0.4.0)
# Requirement already satisfied: PyYAML in /opt/conda/lib/python3.10/site-packages (from wandb) (6.0.1)
# Requirement already satisfied: setproctitle in /opt/conda/lib/python3.10/site-packages (from wandb) (1.3.3)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (from wandb) (68.1.2)
# Requirement already satisfied: appdirs>=1.4.3 in /opt/conda/lib/python3.10/site-packages (from wandb) (1.4.4)
# Requirement already satisfied: protobuf!=4.21.0,<5,>=3.19.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (3.20.3)
# Requirement already satisfied: six>=1.4.0 in /opt/conda/lib/python3.10/site-packages (from docker-pycreds>=0.4.0->wandb) (1.16.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /opt/conda/lib/python3.10/site-packages (from GitPython!=3.1.29,>=1.0.0->wandb) (4.0.10)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (2023.7.22)
# Requirement already satisfied: smmap<6,>=3.0.1 in /opt/conda/lib/python3.10/site-packages (from gitdb<5,>=4.0.1->GitPython!=3.1.29,>=1.0.0->wandb) (5.0.0)

# %%
from torchsummary import summary
from torchgeometry.losses import one_hot
import os
import pandas as pd
import numpy as np
from PIL import Image
import cv2
import time
import imageio
import matplotlib.pyplot as plt
import time
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.optim import lr_scheduler
from torch import Tensor
from torch.utils.data import Dataset, DataLoader, random_split
from torchvision.transforms import Resize, PILToTensor, ToPILImage, Compose, InterpolationMode
from torchvision.transforms import RandomHorizontalFlip, RandomVerticalFlip, RandomRotation
from collections import OrderedDict
import wandb

# %%
# !nvidia-smi -L
# Out:
# GPU 0: Tesla T4 (UUID: GPU-20dee256-3392-4866-11b1-40104dcf67ab)
# GPU 1: Tesla T4 (UUID: GPU-803b0cc5-ad72-22c0-4cb8-0100c55e9b51)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda')

# %% [markdown]
# # PARAMETERS

# %%
# Number of class in the data set (3: neoplastic, non neoplastic, background)
num_classes = 3

# Number of epoch
epochs = 100

# Hyperparameters for training
learning_rate = 2e-04
batch_size = 4
display_step = 50


# Initialize lists to keep track of loss and accuracy
loss_epoch_array = []
train_accuracy = []
test_accuracy = []
valid_accuracy = []

# %% [markdown]
# # DATALOADER

# %%
train_transform = Compose([
    Resize((256, 256), interpolation=InterpolationMode.BILINEAR),  # Adjust the size according to your needs
    RandomHorizontalFlip(),
    RandomVerticalFlip(),
    RandomRotation(degrees = 30),
    PILToTensor(),  # Convert the PIL image to a PyTorch tensor
    lambda x: x.float(),
])
valid_transform = Compose([Resize((256, 256), interpolation=InterpolationMode.BILINEAR),
                     PILToTensor()])

# %%
class UNetDataClass(Dataset):
    def __init__(self, images_path, masks_path, train_transform, valid_transform):
        super(UNetDataClass, self).__init__()

        images_list = os.listdir(images_path)
        masks_list = os.listdir(masks_path)

        images_list = [images_path + image_name for image_name in images_list]
        masks_list = [masks_path + mask_name for mask_name in masks_list]

        self.images_list = images_list
        self.masks_list = masks_list
        self.train_transform = train_transform
        self.valid_transform = valid_transform

    def __getitem__(self, index):
        img_path = self.images_list[index]
        mask_path = self.masks_list[index]

        # Open image and mask
        data = Image.open(img_path)
        label = Image.open(mask_path)

        # Normalize
        data = self.train_transform(data) / 255
        label = self.valid_transform(label) / 255

        label = torch.where(label>0.65, 1.0, 0.0)

        label[2, :, :] = 0.0001
        label = torch.argmax(label, 0).type(torch.int64)

        return data, label

    def __len__(self):
        return len(self.images_list)

# %%
images_path = '/kaggle/input/bkai-igh-neopolyp/train/train/'
masks_path = '/kaggle/input/bkai-igh-neopolyp/train_gt/train_gt/'

# %%
unet_dataset = UNetDataClass(images_path, masks_path, train_transform, valid_transform)

# %%
train_size = 0.8
valid_size = 0.2

# %%
train_set, valid_set = random_split(unet_dataset,
                                    [int(train_size * len(unet_dataset)) ,
                                     int(valid_size * len(unet_dataset))])

# %%
train_dataloader = DataLoader(train_set, batch_size=batch_size, shuffle=True)
valid_dataloader = DataLoader(valid_set, batch_size=batch_size, shuffle=True)

# %% [markdown]
# # MODEL

# %% [markdown]
# ## Encoder Block

# %%
class encoder_block(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(encoder_block, self).__init__()

        self.conv1 = nn.Conv2d(in_channels, out_channels, kernel_size=3, stride=1, padding='same')
        self.conv2 = nn.Conv2d(out_channels, out_channels, kernel_size=3, stride=1, padding='same')

        self.bn1 = nn.BatchNorm2d(out_channels)
        self.bn2 = nn.BatchNorm2d(out_channels)

        self.relu = nn.ReLU()
        self.dropout = nn.Dropout(p=0.3)
        self.max_pool = nn.MaxPool2d(kernel_size=2, stride=2)

    def forward(self, x):
        x = self.conv1(x)
        x = self.bn1(x)
        x = self.relu(x)

        x = self.dropout(x)

        x = self.conv2(x)
        x = self.bn2(x)
        x = self.relu(x)

        next_layer = self.max_pool(x)
        skip_layer = x

        return next_layer, skip_layer

# %% [markdown]
# ## Decoder block

# %%
class decoder_block(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(decoder_block, self).__init__()

        self.transpose_conv = nn.ConvTranspose2d(in_channels, out_channels, kernel_size=2, stride=2)

        self.conv1 = nn.Conv2d(2 * out_channels, out_channels, kernel_size=3, stride=1, padding='same')
        self.conv2 = nn.Conv2d(out_channels, out_channels, kernel_size=3, stride=1, padding='same')

        self.bn1 = nn.BatchNorm2d(out_channels)
        self.bn2 = nn.BatchNorm2d(out_channels)

        self.relu = nn.ReLU()
        self.dropout = nn.Dropout(p=0.3)

    def forward(self, x, skip_layer):
        x = self.transpose_conv(x)
        x = torch.cat([x, skip_layer], axis=1)

        x = self.conv1(x)
        x = self.bn1(x)
        x = self.relu(x)

        x = self.dropout(x)

        x = self.conv2(x)
        x = self.bn2(x)
        x = self.relu(x)

        return x

# %% [markdown]
# ## Bottle neck

# %%
class bottleneck_block(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(bottleneck_block, self).__init__()

        self.conv1 = nn.Conv2d(in_channels, out_channels, kernel_size=3, stride=1, padding='same')
        self.conv2 = nn.Conv2d(out_channels, out_channels, kernel_size=3, stride=1, padding='same')

        self.bn1 = nn.BatchNorm2d(out_channels)
        self.bn2 = nn.BatchNorm2d(out_channels)

        self.relu = nn.ReLU()
        self.dropout = nn.Dropout(p=0.3)

    def forward(self, x):
        x = self.conv1(x)
        x = self.bn1(x)
        x = self.relu(x)

        x = self.dropout(x)

        x = self.conv2(x)
        x = self.bn2(x)
        x = self.relu(x)

        return x

# %% [markdown]
# ## Unet model

# %%
# UNet model
class UNet(nn.Module):
    def __init__(self, n_class=3):
        super(UNet, self).__init__()
        # Encoder blocks
        self.enc1 = encoder_block(3, 64)
        self.enc2 = encoder_block(64, 128)
        self.enc3 = encoder_block(128, 256)
        self.enc4 = encoder_block(256, 512)

        # Bottleneck block
        self.bottleneck = bottleneck_block(512, 1024)

        # Decoder blocks
        self.dec1 = decoder_block(1024, 512)
        self.dec2 = decoder_block(512, 256)
        self.dec3 = decoder_block(256, 128)
        self.dec4 = decoder_block(128, 64)

        # 1x1 convolution
        self.out = nn.Conv2d(64, n_class, kernel_size=1, padding='same')

    def forward(self, image):
        n1, s1 = self.enc1(image)
        n2, s2 = self.enc2(n1)
        n3, s3 = self.enc3(n2)
        n4, s4 = self.enc4(n3)

        n5 = self.bottleneck(n4)

        n6 = self.dec1(n5, s4)
        n7 = self.dec2(n6, s3)
        n8 = self.dec3(n7, s2)
        n9 = self.dec4(n8, s1)

        output = self.out(n9)

        return output

# %% [markdown]
# # LOSS FUNCTION

# %%
class CEDiceLoss(nn.Module):
    def __init__(self, weights) -> None:
        super(CEDiceLoss, self).__init__()
        self.eps: float = 1e-6
        self.weights: torch.Tensor = weights

    def forward(
            self,
            input: torch.Tensor,
            target: torch.Tensor) -> torch.Tensor:
        if not torch.is_tensor(input):
            raise TypeError("Input type is not a torch.Tensor. Got {}"
                            .format(type(input)))
        if not len(input.shape) == 4:
            raise ValueError("Invalid input shape, we expect BxNxHxW. Got: {}"
                             .format(input.shape))
        if not input.shape[-2:] == target.shape[-2:]:
            raise ValueError("input and target shapes must be the same. Got: {}"
                             .format(input.shape, input.shape))
        if not input.device == target.device:
            raise ValueError(
                "input and target must be in the same device. Got: {}" .format(
                    input.device, target.device))
        if not self.weights.shape[1] == input.shape[1]:
            raise ValueError("The number of weights must equal the number of classes")
        if not torch.sum(self.weights).item() == 1:
            raise ValueError("The sum of all weights must equal 1")

        # cross entropy loss
        celoss = nn.CrossEntropyLoss(self.weights)(input, target)

        # compute softmax over the classes axis
        input_soft = F.softmax(input, dim=1)

        # create the labels one hot tensor
        target_one_hot = one_hot(target, num_classes=input.shape[1],
                                 device=input.device, dtype=input.dtype)

        # compute the actual dice score
        dims = (2, 3)
        intersection = torch.sum(input_soft * target_one_hot, dims)
        cardinality = torch.sum(input_soft + target_one_hot, dims)

        dice_score = 2. * intersection / (cardinality + self.eps)

        dice_score = torch.sum(dice_score * self.weights, dim=1)

        return torch.mean(1. - dice_score) + celoss

# %% [markdown]
# # TRAINING

# %% [markdown]
# ## Initialize weights

# %%
def weights_init(model):
    if isinstance(model, nn.Linear):
        # Xavier Distribution
        torch.nn.init.xavier_uniform_(model.weight)

# %%
def save_model(model, optimizer, path):
    checkpoint = {
        "model": model.state_dict(),
        "optimizer": optimizer.state_dict(),
    }
    torch.save(checkpoint, path)

def load_model(model, optimizer, path):
    checkpoint = torch.load(path)
    model.load_state_dict(checkpoint["model"])
    optimizer.load_state_dict(checkpoint['optimizer'])
    return model, optimizer

# %% [markdown]
# ## Train model

# %%
# Train function for each epoch
def train(train_dataloader, valid_dataloader,learing_rate_scheduler, epoch, display_step):
    print(f"Start epoch #{epoch+1}, learning rate for this epoch: {learing_rate_scheduler.get_last_lr()}")
    start_time = time.time()
    train_loss_epoch = 0
    test_loss_epoch = 0
    last_loss = 999999999
    model.train()
    for i, (data,targets) in enumerate(train_dataloader):

        # Load data into GPU
        data, targets = data.to(device), targets.to(device)

        optimizer.zero_grad()
        outputs = model(data)

        # Backpropagation, compute gradients
        loss = loss_function(outputs, targets.long())
        loss.backward()

        # Apply gradients
        optimizer.step()

        # Save loss
        train_loss_epoch += loss.item()
        if (i+1) % display_step == 0:
#             accuracy = float(test(test_loader))
            print('Train Epoch: {} [{}/{} ({}%)]\tLoss: {:.4f}'.format(
                epoch + 1, (i+1) * len(data), len(train_dataloader.dataset), 100 * (i+1) * len(data) / len(train_dataloader.dataset),
                loss.item()))

    print(f"Done epoch #{epoch+1}, time for this epoch: {time.time()-start_time}s")
    train_loss_epoch/= (i + 1)

    # Evaluate the validation set
    model.eval()
    with torch.no_grad():
        for data, target in valid_dataloader:
            data, target = data.to(device), target.to(device)
            test_output = model(data)
            test_loss = loss_function(test_output, target)
            test_loss_epoch += test_loss.item()

    test_loss_epoch/= (i+1)

    return train_loss_epoch , test_loss_epoch

# %% [markdown]
# ## Test function

# %%
# Test function
def test(dataloader):
    test_loss = 0
    correct = 0
    with torch.no_grad():
        for i, (data, targets) in enumerate(dataloader):
            data, targets = data.to(device), targets.to(device)
            outputs = model(data)
            _, pred = torch.max(outputs, 1)
            test_loss += targets.size(0)
            correct += torch.sum(pred == targets).item()
    return correct / test_loss

# %%
pretrained_path = '/kaggle/working/unet_model.pth'

# %%
model = UNet()
model.apply(weights_init)
checkpoint = torch.load(pretrained_path)

# new_state_dict = OrderedDict()
# for k, v in checkpoint['model'].items():
#     name = k[7:] # remove `module.`
#     new_state_dict[name] = v
# load params
# model.load_state_dict(new_state_dict)
model = nn.DataParallel(model)
model.to(device)
# Out:
# DataParallel(
#   (module): UNet(
#     (enc1): encoder_block(
#       (conv1): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=same)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=same)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#       (dropout): Dropout(p=0.3, inplace=False)
#       (max_pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#     (enc2): encoder_block(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=same)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=same)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#       (dropout): Dropout(p=0.3, inplace=False)
#       (max_pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#     (enc3): encoder_block(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=same)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=same)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#       (dropout): Dropout(p=0.3, inplace=False)
#       (max_pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#     (enc4): encoder_block(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=same)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=same)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#       (dropout): Dropout(p=0.3, inplace=False)
#       (max_pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#     (bottleneck): bottleneck_block(
#       (conv1): Conv2d(512, 1024, kernel_size=(3, 3), stride=(1, 1), padding=same)
#       (conv2): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=same)
#       (bn1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#       (dropout): Dropout(p=0.3, inplace=False)
#     )
#     (dec1): decoder_block(
#       (transpose_conv): ConvTranspose2d(1024, 512, kernel_size=(2, 2), stride=(2, 2))
#       (conv1): Conv2d(1024, 512, kernel_size=(3, 3), stride=(1, 1), padding=same)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=same)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#       (dropout): Dropout(p=0.3, inplace=False)
#     )
#     (dec2): decoder_block(
#       (transpose_conv): ConvTranspose2d(512, 256, kernel_size=(2, 2), stride=(2, 2))
#       (conv1): Conv2d(512, 256, kernel_size=(3, 3), stride=(1, 1), padding=same)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=same)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#       (dropout): Dropout(p=0.3, inplace=False)
#     )
#     (dec3): decoder_block(
#       (transpose_conv): ConvTranspose2d(256, 128, kernel_size=(2, 2), stride=(2, 2))
#       (conv1): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=same)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=same)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#       (dropout): Dropout(p=0.3, inplace=False)
#     )
#     (dec4): decoder_block(
#       (transpose_conv): ConvTranspose2d(128, 64, kernel_size=(2, 2), stride=(2, 2))
#       (conv1): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=same)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=same)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#       (dropout): Dropout(p=0.3, inplace=False)
#     )
#     (out): Conv2d(64, 3, kernel_size=(1, 1), stride=(1, 1), padding=same)
#   )
# )

# %%
import torch
print(torch.cuda.is_available())
import torchvision
weights = torch.Tensor([[0.4, 0.55, 0.05]]).cuda()
loss_function = CEDiceLoss(weights)

# Define the optimizer (Adam optimizer)
optimizer = optim.Adam(params=model.parameters(), lr=learning_rate)
# optimizer.load_state_dict(checkpoint['optimizer'])

# Learning rate scheduler
learing_rate_scheduler = lr_scheduler.StepLR(optimizer, step_size=4, gamma=0.6)

checkpoint_path = '/kaggle/working/unet_model.pth' #the path to save the trained model
# Out:
# True

# %%
save_model(model, optimizer, checkpoint_path)

# %%
import torch
torch.cuda.empty_cache()
wandb.login(
    key = "c456a83d581dce980c77ae1bf7613173858779c8",
)
wandb.init(project= "PolypSegment")
#wandb.init(timeout=300)
# Training loop
train_loss_array = []
test_loss_array = []
last_loss = 9999999999999
for epoch in range(epochs):
    train_loss_epoch = 0
    test_loss_epoch = 0
    (train_loss_epoch, test_loss_epoch) = train(train_dataloader,
                                              valid_dataloader,
                                              learing_rate_scheduler, epoch, display_step)

    if test_loss_epoch < last_loss:
        save_model(model, optimizer, checkpoint_path)
        last_loss = test_loss_epoch

    learing_rate_scheduler.step()
    train_loss_array.append(train_loss_epoch)
    test_loss_array.append(test_loss_epoch)
    wandb.log({"Train loss": train_loss_epoch, "Valid loss": test_loss_epoch})
    train_accuracy.append(test(train_dataloader))
    valid_accuracy.append(test(valid_dataloader))
    print("Epoch {}: loss: {:.4f}, train accuracy: {:.4f}, valid accuracy:{:.4f}".format(epoch + 1,
                                        train_loss_array[-1], train_accuracy[-1], valid_accuracy[-1]))
# Out:
# wandb: WARNING Calling wandb.login() after wandb.init() has no effect.
# Finishing last run (ID:vi4v43ae) before initializing another...
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Train loss</td><td>█▃▃▂▁▂▁▁</td></tr><tr><td>Valid loss</td><td>█▁▃▁▃▃▃▂</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Train loss</td><td>1.47792</td></tr><tr><td>Valid loss</td><td>0.38833</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">mild-planet-16</strong> at: <a href='https://wandb.ai/hoangtuquyen/PolypSegment/runs/vi4v43ae' target="_blank">https://wandb.ai/hoangtuquyen/PolypSegment/runs/vi4v43ae</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20231117_112119-vi4v43ae/logs</code>
# Successfully finished last run (ID:vi4v43ae). Initializing new run:<br/>
# Tracking run with wandb version 0.16.0
# Run data is saved locally in <code>/kaggle/working/wandb/run-20231117_113746-ey79rmvm</code>
# Syncing run <strong><a href='https://wandb.ai/hoangtuquyen/PolypSegment/runs/ey79rmvm' target="_blank">robust-water-17</a></strong> to <a href='https://wandb.ai/hoangtuquyen/PolypSegment' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/hoangtuquyen/PolypSegment' target="_blank">https://wandb.ai/hoangtuquyen/PolypSegment</a>
#  View run at <a href='https://wandb.ai/hoangtuquyen/PolypSegment/runs/ey79rmvm' target="_blank">https://wandb.ai/hoangtuquyen/PolypSegment/runs/ey79rmvm</a>
# Start epoch #1, learning rate for this epoch: [0.0002]
# Train Epoch: 1 [200/800 (25.0%)]	Loss: 1.6965
# Train Epoch: 1 [400/800 (50.0%)]	Loss: 1.5717
# Train Epoch: 1 [600/800 (75.0%)]	Loss: 1.8562
# Train Epoch: 1 [800/800 (100.0%)]	Loss: 1.6803
# Done epoch #1, time for this epoch: 55.50817847251892s
# Epoch 1: loss: 1.7017, train accuracy: 56632.9800, valid accuracy:55627.9750
# Start epoch #2, learning rate for this epoch: [0.0002]
# Train Epoch: 2 [200/800 (25.0%)]	Loss: 1.6209
# Train Epoch: 2 [400/800 (50.0%)]	Loss: 1.5513
# Train Epoch: 2 [600/800 (75.0%)]	Loss: 1.5396
# Train Epoch: 2 [800/800 (100.0%)]	Loss: 1.5887
# Done epoch #2, time for this epoch: 53.64651083946228s
# Epoch 2: loss: 1.6156, train accuracy: 60859.5875, valid accuracy:60355.8700
# Start epoch #3, learning rate for this epoch: [0.0002]
# Train Epoch: 3 [200/800 (25.0%)]	Loss: 1.7267
# Train Epoch: 3 [400/800 (50.0%)]	Loss: 1.7815
# Train Epoch: 3 [600/800 (75.0%)]	Loss: 1.6092
# Train Epoch: 3 [800/800 (100.0%)]	Loss: 1.5570
# Done epoch #3, time for this epoch: 53.94891047477722s
# Epoch 3: loss: 1.5942, train accuracy: 38649.4575, valid accuracy:37618.7250
# Start epoch #4, learning rate for this epoch: [0.0002]
# Train Epoch: 4 [200/800 (25.0%)]	Loss: 1.8012
# Train Epoch: 4 [400/800 (50.0%)]	Loss: 1.4158
# Train Epoch: 4 [600/800 (75.0%)]	Loss: 1.7039
# Train Epoch: 4 [800/800 (100.0%)]	Loss: 1.5644
# Done epoch #4, time for this epoch: 53.54117727279663s
# Epoch 4: loss: 1.5268, train accuracy: 44668.3363, valid accuracy:44684.6200
# Start epoch #5, learning rate for this epoch: [0.00012]
# Train Epoch: 5 [200/800 (25.0%)]	Loss: 1.6885
# Train Epoch: 5 [400/800 (50.0%)]	Loss: 1.3105
# Train Epoch: 5 [600/800 (75.0%)]	Loss: 2.8284
# Train Epoch: 5 [800/800 (100.0%)]	Loss: 1.5001
# Done epoch #5, time for this epoch: 54.843750953674316s
# Epoch 5: loss: 1.5072, train accuracy: 59916.3750, valid accuracy:59519.1800
# Start epoch #6, learning rate for this epoch: [0.00012]
# Train Epoch: 6 [200/800 (25.0%)]	Loss: 1.7059
# Train Epoch: 6 [400/800 (50.0%)]	Loss: 1.4132
# Train Epoch: 6 [600/800 (75.0%)]	Loss: 1.7906
# Train Epoch: 6 [800/800 (100.0%)]	Loss: 1.3208
# Done epoch #6, time for this epoch: 53.9721839427948s
# Epoch 6: loss: 1.5007, train accuracy: 59159.3225, valid accuracy:58254.2350
# Start epoch #7, learning rate for this epoch: [0.00012]
# Train Epoch: 7 [200/800 (25.0%)]	Loss: 1.5333
# Train Epoch: 7 [400/800 (50.0%)]	Loss: 1.4582
# Train Epoch: 7 [600/800 (75.0%)]	Loss: 1.3890
# Train Epoch: 7 [800/800 (100.0%)]	Loss: 1.5677
# Done epoch #7, time for this epoch: 53.46560597419739s
# Epoch 7: loss: 1.4990, train accuracy: 61976.2250, valid accuracy:61690.4500
# Start epoch #8, learning rate for this epoch: [0.00012]
# Train Epoch: 8 [200/800 (25.0%)]	Loss: 1.5299
# Train Epoch: 8 [400/800 (50.0%)]	Loss: 1.4420
# Train Epoch: 8 [600/800 (75.0%)]	Loss: 1.4266
# Train Epoch: 8 [800/800 (100.0%)]	Loss: 1.4415
# Done epoch #8, time for this epoch: 53.52412271499634s
# Epoch 8: loss: 1.4951, train accuracy: 61916.8063, valid accuracy:61579.0500
# Start epoch #9, learning rate for this epoch: [7.2e-05]
# Train Epoch: 9 [200/800 (25.0%)]	Loss: 1.5424
# Train Epoch: 9 [400/800 (50.0%)]	Loss: 1.3071
# Train Epoch: 9 [600/800 (75.0%)]	Loss: 1.4082
# Train Epoch: 9 [800/800 (100.0%)]	Loss: 1.6482
# Done epoch #9, time for this epoch: 53.298919916152954s
# Epoch 9: loss: 1.4911, train accuracy: 59733.0462, valid accuracy:59098.6250
# Start epoch #10, learning rate for this epoch: [7.2e-05]
# Train Epoch: 10 [200/800 (25.0%)]	Loss: 1.8266
# Train Epoch: 10 [400/800 (50.0%)]	Loss: 1.3683
# Train Epoch: 10 [600/800 (75.0%)]	Loss: 1.4401
# Train Epoch: 10 [800/800 (100.0%)]	Loss: 1.6693
# Done epoch #10, time for this epoch: 53.486934185028076s
# Epoch 10: loss: 1.4952, train accuracy: 60563.0500, valid accuracy:60039.8050
# Start epoch #11, learning rate for this epoch: [7.2e-05]
# Train Epoch: 11 [200/800 (25.0%)]	Loss: 1.4938
# Train Epoch: 11 [400/800 (50.0%)]	Loss: 1.7221
# Train Epoch: 11 [600/800 (75.0%)]	Loss: 1.4481
# Train Epoch: 11 [800/800 (100.0%)]	Loss: 1.5669
# Done epoch #11, time for this epoch: 54.13908553123474s
# Epoch 11: loss: 1.4845, train accuracy: 59118.7337, valid accuracy:58902.6400
# Start epoch #12, learning rate for this epoch: [7.2e-05]
# Train Epoch: 12 [200/800 (25.0%)]	Loss: 1.7256
# Train Epoch: 12 [400/800 (50.0%)]	Loss: 1.3852
# Train Epoch: 12 [600/800 (75.0%)]	Loss: 2.1600
# Train Epoch: 12 [800/800 (100.0%)]	Loss: 1.4889
# Done epoch #12, time for this epoch: 53.69620084762573s
# Epoch 12: loss: 1.4855, train accuracy: 60875.8900, valid accuracy:60538.9650
# Start epoch #13, learning rate for this epoch: [4.32e-05]
# Train Epoch: 13 [200/800 (25.0%)]	Loss: 1.5268
# Train Epoch: 13 [400/800 (50.0%)]	Loss: 1.4825
# Train Epoch: 13 [600/800 (75.0%)]	Loss: 1.4957
# Train Epoch: 13 [800/800 (100.0%)]	Loss: 1.3085
# Done epoch #13, time for this epoch: 54.110973834991455s
# Epoch 13: loss: 1.4821, train accuracy: 59727.1425, valid accuracy:59329.6350
# Start epoch #14, learning rate for this epoch: [4.32e-05]
# Train Epoch: 14 [200/800 (25.0%)]	Loss: 1.3345
# Train Epoch: 14 [400/800 (50.0%)]	Loss: 1.7081
# Train Epoch: 14 [600/800 (75.0%)]	Loss: 1.4148
# Train Epoch: 14 [800/800 (100.0%)]	Loss: 1.3266
# Done epoch #14, time for this epoch: 53.895620584487915s
# Epoch 14: loss: 1.4825, train accuracy: 61290.7275, valid accuracy:60814.8400
# Start epoch #15, learning rate for this epoch: [4.32e-05]
# Train Epoch: 15 [200/800 (25.0%)]	Loss: 1.7444
# Train Epoch: 15 [400/800 (50.0%)]	Loss: 1.3899
# Train Epoch: 15 [600/800 (75.0%)]	Loss: 1.3864
# Train Epoch: 15 [800/800 (100.0%)]	Loss: 1.4325
# Done epoch #15, time for this epoch: 53.3992486000061s
# Epoch 15: loss: 1.4773, train accuracy: 59160.1338, valid accuracy:58952.4500
# Start epoch #16, learning rate for this epoch: [4.32e-05]
# Train Epoch: 16 [200/800 (25.0%)]	Loss: 1.8238
# Train Epoch: 16 [400/800 (50.0%)]	Loss: 1.5123
# Train Epoch: 16 [600/800 (75.0%)]	Loss: 1.4074
# Train Epoch: 16 [800/800 (100.0%)]	Loss: 1.4734
# Done epoch #16, time for this epoch: 53.515026569366455s
# Epoch 16: loss: 1.4835, train accuracy: 60379.1925, valid accuracy:60060.6900
# Start epoch #17, learning rate for this epoch: [2.592e-05]
# Train Epoch: 17 [200/800 (25.0%)]	Loss: 1.5235
# Train Epoch: 17 [400/800 (50.0%)]	Loss: 1.2906
# Train Epoch: 17 [600/800 (75.0%)]	Loss: 1.5190
# Train Epoch: 17 [800/800 (100.0%)]	Loss: 1.4432
# Done epoch #17, time for this epoch: 53.629841327667236s
# Epoch 17: loss: 1.4738, train accuracy: 59492.9600, valid accuracy:59279.2800
# Start epoch #18, learning rate for this epoch: [2.592e-05]
# Train Epoch: 18 [200/800 (25.0%)]	Loss: 1.3469
# Train Epoch: 18 [400/800 (50.0%)]	Loss: 1.4296
# Train Epoch: 18 [600/800 (75.0%)]	Loss: 1.4060
# Train Epoch: 18 [800/800 (100.0%)]	Loss: 1.4852
# Done epoch #18, time for this epoch: 53.4810996055603s
# Epoch 18: loss: 1.4829, train accuracy: 61332.5212, valid accuracy:61231.9000
# Start epoch #19, learning rate for this epoch: [2.592e-05]
# Train Epoch: 19 [200/800 (25.0%)]	Loss: 1.7187
# Train Epoch: 19 [400/800 (50.0%)]	Loss: 1.6850
# Train Epoch: 19 [600/800 (75.0%)]	Loss: 2.0805
# Train Epoch: 19 [800/800 (100.0%)]	Loss: 1.5081
# Done epoch #19, time for this epoch: 53.47713804244995s
# Epoch 19: loss: 1.4845, train accuracy: 61121.6263, valid accuracy:60784.0600
# Start epoch #20, learning rate for this epoch: [2.592e-05]
# Train Epoch: 20 [200/800 (25.0%)]	Loss: 1.4390
# Train Epoch: 20 [400/800 (50.0%)]	Loss: 1.4873
# Train Epoch: 20 [600/800 (75.0%)]	Loss: 1.5328
# Train Epoch: 20 [800/800 (100.0%)]	Loss: 1.3125
# Done epoch #20, time for this epoch: 53.68393111228943s
# Epoch 20: loss: 1.4751, train accuracy: 60710.0663, valid accuracy:60538.6150
# Start epoch #21, learning rate for this epoch: [1.5552e-05]
# Train Epoch: 21 [200/800 (25.0%)]	Loss: 1.3996
# Train Epoch: 21 [400/800 (50.0%)]	Loss: 1.3584
# Train Epoch: 21 [600/800 (75.0%)]	Loss: 1.3870
# Train Epoch: 21 [800/800 (100.0%)]	Loss: 1.3694
# Done epoch #21, time for this epoch: 53.53601264953613s
# Epoch 21: loss: 1.4758, train accuracy: 60927.8825, valid accuracy:60613.4650
# Start epoch #22, learning rate for this epoch: [1.5552e-05]
# Train Epoch: 22 [200/800 (25.0%)]	Loss: 1.4848
# Train Epoch: 22 [400/800 (50.0%)]	Loss: 1.4509
# Train Epoch: 22 [600/800 (75.0%)]	Loss: 1.5441
# Train Epoch: 22 [800/800 (100.0%)]	Loss: 1.3359
# Done epoch #22, time for this epoch: 53.589226961135864s
# Epoch 22: loss: 1.4740, train accuracy: 59376.4987, valid accuracy:58943.8850
# Start epoch #23, learning rate for this epoch: [1.5552e-05]
# Train Epoch: 23 [200/800 (25.0%)]	Loss: 1.5414
# Train Epoch: 23 [400/800 (50.0%)]	Loss: 1.2979
# Train Epoch: 23 [600/800 (75.0%)]	Loss: 1.5600
# Train Epoch: 23 [800/800 (100.0%)]	Loss: 1.5163
# Done epoch #23, time for this epoch: 53.68138337135315s
# Epoch 23: loss: 1.4758, train accuracy: 60991.9925, valid accuracy:61001.1050
# Start epoch #24, learning rate for this epoch: [1.5552e-05]
# Train Epoch: 24 [200/800 (25.0%)]	Loss: 1.3539
# Train Epoch: 24 [400/800 (50.0%)]	Loss: 1.3682
# Train Epoch: 24 [600/800 (75.0%)]	Loss: 1.3894
# Train Epoch: 24 [800/800 (100.0%)]	Loss: 1.3383
# Done epoch #24, time for this epoch: 53.280389070510864s
# Epoch 24: loss: 1.4832, train accuracy: 60162.8613, valid accuracy:59873.5100
# Start epoch #25, learning rate for this epoch: [9.3312e-06]
# Train Epoch: 25 [200/800 (25.0%)]	Loss: 1.4165
# Train Epoch: 25 [400/800 (50.0%)]	Loss: 1.5821
# Train Epoch: 25 [600/800 (75.0%)]	Loss: 1.3536
# Train Epoch: 25 [800/800 (100.0%)]	Loss: 2.0325
# Done epoch #25, time for this epoch: 53.462767124176025s
# Epoch 25: loss: 1.4749, train accuracy: 60755.4887, valid accuracy:60567.5000
# Start epoch #26, learning rate for this epoch: [9.3312e-06]
# Train Epoch: 26 [200/800 (25.0%)]	Loss: 1.4949
# Train Epoch: 26 [400/800 (50.0%)]	Loss: 1.3623
# Train Epoch: 26 [600/800 (75.0%)]	Loss: 1.4882
# Train Epoch: 26 [800/800 (100.0%)]	Loss: 1.3495
# Done epoch #26, time for this epoch: 53.36570644378662s
# Epoch 26: loss: 1.4720, train accuracy: 60274.9750, valid accuracy:59957.1650
# Start epoch #27, learning rate for this epoch: [9.3312e-06]
# Train Epoch: 27 [200/800 (25.0%)]	Loss: 1.5884
# Train Epoch: 27 [400/800 (50.0%)]	Loss: 1.5638
# Train Epoch: 27 [600/800 (75.0%)]	Loss: 1.3908
# Train Epoch: 27 [800/800 (100.0%)]	Loss: 1.4055
# Done epoch #27, time for this epoch: 53.273534536361694s
# Epoch 27: loss: 1.4742, train accuracy: 59991.8138, valid accuracy:59731.0150
# Start epoch #28, learning rate for this epoch: [9.3312e-06]
# Train Epoch: 28 [200/800 (25.0%)]	Loss: 1.3684
# Train Epoch: 28 [400/800 (50.0%)]	Loss: 1.3659
# Train Epoch: 28 [600/800 (75.0%)]	Loss: 1.3533
# Train Epoch: 28 [800/800 (100.0%)]	Loss: 1.4649
# Done epoch #28, time for this epoch: 53.43431782722473s
# Epoch 28: loss: 1.4769, train accuracy: 60620.9812, valid accuracy:60392.1750
# Start epoch #29, learning rate for this epoch: [5.59872e-06]
# Train Epoch: 29 [200/800 (25.0%)]	Loss: 1.3834
# Train Epoch: 29 [400/800 (50.0%)]	Loss: 1.3011
# Train Epoch: 29 [600/800 (75.0%)]	Loss: 1.5670
# Train Epoch: 29 [800/800 (100.0%)]	Loss: 1.4441
# Done epoch #29, time for this epoch: 53.33764886856079s
# Epoch 29: loss: 1.4722, train accuracy: 60840.8288, valid accuracy:60665.8650
# Start epoch #30, learning rate for this epoch: [5.59872e-06]
# Train Epoch: 30 [200/800 (25.0%)]	Loss: 1.4104
# Train Epoch: 30 [400/800 (50.0%)]	Loss: 1.3994
# Train Epoch: 30 [600/800 (75.0%)]	Loss: 1.4515
# Train Epoch: 30 [800/800 (100.0%)]	Loss: 1.5187
# Done epoch #30, time for this epoch: 53.28611636161804s
# Epoch 30: loss: 1.4695, train accuracy: 59873.2237, valid accuracy:59389.1700
# Start epoch #31, learning rate for this epoch: [5.59872e-06]
# Train Epoch: 31 [200/800 (25.0%)]	Loss: 1.3720
# Train Epoch: 31 [400/800 (50.0%)]	Loss: 1.3513
# Train Epoch: 31 [600/800 (75.0%)]	Loss: 1.3478
# Train Epoch: 31 [800/800 (100.0%)]	Loss: 1.4993
# Done epoch #31, time for this epoch: 53.46644830703735s
# Epoch 31: loss: 1.4744, train accuracy: 60395.3675, valid accuracy:60042.2800
# Start epoch #32, learning rate for this epoch: [5.59872e-06]
# Train Epoch: 32 [200/800 (25.0%)]	Loss: 1.3653
# Train Epoch: 32 [400/800 (50.0%)]	Loss: 1.3387
# Train Epoch: 32 [600/800 (75.0%)]	Loss: 1.4576
# Train Epoch: 32 [800/800 (100.0%)]	Loss: 1.5034
# Done epoch #32, time for this epoch: 53.73648238182068s
# Epoch 32: loss: 1.4705, train accuracy: 60656.7738, valid accuracy:60720.2900
# Start epoch #33, learning rate for this epoch: [3.359232e-06]
# Train Epoch: 33 [200/800 (25.0%)]	Loss: 1.5047
# Train Epoch: 33 [400/800 (50.0%)]	Loss: 1.4513
# Train Epoch: 33 [600/800 (75.0%)]	Loss: 1.6555
# Train Epoch: 33 [800/800 (100.0%)]	Loss: 1.4277
# Done epoch #33, time for this epoch: 53.231738805770874s
# Epoch 33: loss: 1.4730, train accuracy: 60783.1775, valid accuracy:60402.1100
# Start epoch #34, learning rate for this epoch: [3.359232e-06]
# Train Epoch: 34 [200/800 (25.0%)]	Loss: 1.2250
# Train Epoch: 34 [400/800 (50.0%)]	Loss: 1.3888
# Train Epoch: 34 [600/800 (75.0%)]	Loss: 1.2686
# Train Epoch: 34 [800/800 (100.0%)]	Loss: 1.6392
# Done epoch #34, time for this epoch: 53.66245985031128s
# Epoch 34: loss: 1.4712, train accuracy: 61182.1275, valid accuracy:60946.5000
# Start epoch #35, learning rate for this epoch: [3.359232e-06]
# Train Epoch: 35 [200/800 (25.0%)]	Loss: 1.7602
# Train Epoch: 35 [400/800 (50.0%)]	Loss: 1.5648
# Train Epoch: 35 [600/800 (75.0%)]	Loss: 1.5622
# Train Epoch: 35 [800/800 (100.0%)]	Loss: 1.5601
# Done epoch #35, time for this epoch: 53.929314851760864s
# Epoch 35: loss: 1.4699, train accuracy: 60620.2213, valid accuracy:60287.5350
# Start epoch #36, learning rate for this epoch: [3.359232e-06]
# Train Epoch: 36 [200/800 (25.0%)]	Loss: 1.2562
# Train Epoch: 36 [400/800 (50.0%)]	Loss: 1.8413
# Train Epoch: 36 [600/800 (75.0%)]	Loss: 1.5056
# Train Epoch: 36 [800/800 (100.0%)]	Loss: 1.5096
# Done epoch #36, time for this epoch: 53.334083795547485s
# Epoch 36: loss: 1.4709, train accuracy: 61243.5575, valid accuracy:61237.1250
# Start epoch #37, learning rate for this epoch: [2.0155392e-06]
# Train Epoch: 37 [200/800 (25.0%)]	Loss: 1.5053
# Train Epoch: 37 [400/800 (50.0%)]	Loss: 1.5396
# Train Epoch: 37 [600/800 (75.0%)]	Loss: 1.6350
# Train Epoch: 37 [800/800 (100.0%)]	Loss: 1.5766
# Done epoch #37, time for this epoch: 53.5144624710083s
# Epoch 37: loss: 1.4739, train accuracy: 60661.5075, valid accuracy:60358.7500
# Start epoch #38, learning rate for this epoch: [2.0155392e-06]
# Train Epoch: 38 [200/800 (25.0%)]	Loss: 1.3145
# Train Epoch: 38 [400/800 (50.0%)]	Loss: 1.7192
# Train Epoch: 38 [600/800 (75.0%)]	Loss: 1.3899
# Train Epoch: 38 [800/800 (100.0%)]	Loss: 1.3696
# Done epoch #38, time for this epoch: 53.33083510398865s
# Epoch 38: loss: 1.4739, train accuracy: 61162.4975, valid accuracy:61212.6100
# Start epoch #39, learning rate for this epoch: [2.0155392e-06]
# Train Epoch: 39 [200/800 (25.0%)]	Loss: 1.4086
# Train Epoch: 39 [400/800 (50.0%)]	Loss: 1.4353
# Train Epoch: 39 [600/800 (75.0%)]	Loss: 1.2881
# Train Epoch: 39 [800/800 (100.0%)]	Loss: 1.7210
# Done epoch #39, time for this epoch: 53.151472330093384s
# Epoch 39: loss: 1.4740, train accuracy: 61215.5088, valid accuracy:61053.7450
# Start epoch #40, learning rate for this epoch: [2.0155392e-06]
# Train Epoch: 40 [200/800 (25.0%)]	Loss: 1.4614
# Train Epoch: 40 [400/800 (50.0%)]	Loss: 1.4393
# Train Epoch: 40 [600/800 (75.0%)]	Loss: 1.6060
# Train Epoch: 40 [800/800 (100.0%)]	Loss: 1.3895
# Done epoch #40, time for this epoch: 54.09048271179199s
# Epoch 40: loss: 1.4680, train accuracy: 60904.3712, valid accuracy:60602.4900
# Start epoch #41, learning rate for this epoch: [1.20932352e-06]
# Train Epoch: 41 [200/800 (25.0%)]	Loss: 1.3540
# Train Epoch: 41 [400/800 (50.0%)]	Loss: 1.4692
# Train Epoch: 41 [600/800 (75.0%)]	Loss: 1.5108
# Train Epoch: 41 [800/800 (100.0%)]	Loss: 1.3873
# Done epoch #41, time for this epoch: 53.58817744255066s
# Epoch 41: loss: 1.4707, train accuracy: 60841.3150, valid accuracy:60452.6900
# Start epoch #42, learning rate for this epoch: [1.20932352e-06]
# Train Epoch: 42 [200/800 (25.0%)]	Loss: 1.4845
# Train Epoch: 42 [400/800 (50.0%)]	Loss: 1.7419
# Train Epoch: 42 [600/800 (75.0%)]	Loss: 1.2212
# Train Epoch: 42 [800/800 (100.0%)]	Loss: 1.3466
# Done epoch #42, time for this epoch: 53.272581338882446s
# Epoch 42: loss: 1.4740, train accuracy: 60470.9025, valid accuracy:60232.0800
# Start epoch #43, learning rate for this epoch: [1.20932352e-06]
# Train Epoch: 43 [200/800 (25.0%)]	Loss: 1.1590
# Train Epoch: 43 [400/800 (50.0%)]	Loss: 1.4613
# Train Epoch: 43 [600/800 (75.0%)]	Loss: 1.5692
# Train Epoch: 43 [800/800 (100.0%)]	Loss: 1.4770
# Done epoch #43, time for this epoch: 53.482680320739746s
# Epoch 43: loss: 1.4729, train accuracy: 61131.1212, valid accuracy:61125.1750
# Start epoch #44, learning rate for this epoch: [1.20932352e-06]
# Train Epoch: 44 [200/800 (25.0%)]	Loss: 1.3080
# Train Epoch: 44 [400/800 (50.0%)]	Loss: 1.7066
# Train Epoch: 44 [600/800 (75.0%)]	Loss: 1.5664
# Train Epoch: 44 [800/800 (100.0%)]	Loss: 1.4269
# Done epoch #44, time for this epoch: 53.60442662239075s
# Epoch 44: loss: 1.4712, train accuracy: 61035.1650, valid accuracy:60808.1000
# Start epoch #45, learning rate for this epoch: [7.25594112e-07]
# Train Epoch: 45 [200/800 (25.0%)]	Loss: 1.7061
# Train Epoch: 45 [400/800 (50.0%)]	Loss: 1.4423
# Train Epoch: 45 [600/800 (75.0%)]	Loss: 1.3325
# Train Epoch: 45 [800/800 (100.0%)]	Loss: 1.5894
# Done epoch #45, time for this epoch: 53.379799604415894s
# Epoch 45: loss: 1.4740, train accuracy: 61011.5687, valid accuracy:60715.3800
# Start epoch #46, learning rate for this epoch: [7.25594112e-07]
# Train Epoch: 46 [200/800 (25.0%)]	Loss: 1.7015
# Train Epoch: 46 [400/800 (50.0%)]	Loss: 1.4628
# Train Epoch: 46 [600/800 (75.0%)]	Loss: 1.5239
# Train Epoch: 46 [800/800 (100.0%)]	Loss: 1.3884
# Done epoch #46, time for this epoch: 53.46731877326965s
# Epoch 46: loss: 1.4696, train accuracy: 60527.2275, valid accuracy:60344.3300
# Start epoch #47, learning rate for this epoch: [7.25594112e-07]
# Train Epoch: 47 [200/800 (25.0%)]	Loss: 1.6244
# Train Epoch: 47 [400/800 (50.0%)]	Loss: 1.4338
# Train Epoch: 47 [600/800 (75.0%)]	Loss: 1.4954
# Train Epoch: 47 [800/800 (100.0%)]	Loss: 1.3785
# Done epoch #47, time for this epoch: 54.1294379234314s
# Epoch 47: loss: 1.4735, train accuracy: 61164.5750, valid accuracy:61050.4700
# Start epoch #48, learning rate for this epoch: [7.25594112e-07]
# Train Epoch: 48 [200/800 (25.0%)]	Loss: 1.3902
# Train Epoch: 48 [400/800 (50.0%)]	Loss: 1.3518
# Train Epoch: 48 [600/800 (75.0%)]	Loss: 1.1720
# Train Epoch: 48 [800/800 (100.0%)]	Loss: 1.4571
# Done epoch #48, time for this epoch: 53.85812854766846s
# Epoch 48: loss: 1.4689, train accuracy: 61283.1288, valid accuracy:60899.4150
# Start epoch #49, learning rate for this epoch: [4.353564672e-07]
# Train Epoch: 49 [200/800 (25.0%)]	Loss: 1.4246
# Train Epoch: 49 [400/800 (50.0%)]	Loss: 1.5744
# Train Epoch: 49 [600/800 (75.0%)]	Loss: 1.4418
# Train Epoch: 49 [800/800 (100.0%)]	Loss: 1.6401
# Done epoch #49, time for this epoch: 53.51265907287598s
# Epoch 49: loss: 1.4730, train accuracy: 60674.5625, valid accuracy:60322.2300
# Start epoch #50, learning rate for this epoch: [4.353564672e-07]
# Train Epoch: 50 [200/800 (25.0%)]	Loss: 1.5063
# Train Epoch: 50 [400/800 (50.0%)]	Loss: 1.6614
# Train Epoch: 50 [600/800 (75.0%)]	Loss: 1.4488
# Train Epoch: 50 [800/800 (100.0%)]	Loss: 1.3656
# Done epoch #50, time for this epoch: 53.803648710250854s
# Epoch 50: loss: 1.4707, train accuracy: 61113.9725, valid accuracy:60951.8100
# Start epoch #51, learning rate for this epoch: [4.353564672e-07]
# Train Epoch: 51 [200/800 (25.0%)]	Loss: 1.2130
# Train Epoch: 51 [400/800 (50.0%)]	Loss: 1.4285
# Train Epoch: 51 [600/800 (75.0%)]	Loss: 1.6991
# Train Epoch: 51 [800/800 (100.0%)]	Loss: 1.3447
# Done epoch #51, time for this epoch: 53.21095633506775s
# Epoch 51: loss: 1.4688, train accuracy: 60567.4313, valid accuracy:60251.4050
# Start epoch #52, learning rate for this epoch: [4.353564672e-07]
# Train Epoch: 52 [200/800 (25.0%)]	Loss: 1.5903
# Train Epoch: 52 [400/800 (50.0%)]	Loss: 1.3448
# Train Epoch: 52 [600/800 (75.0%)]	Loss: 1.3991
# Train Epoch: 52 [800/800 (100.0%)]	Loss: 1.3361
# Done epoch #52, time for this epoch: 54.376402616500854s
# Epoch 52: loss: 1.4682, train accuracy: 61046.8112, valid accuracy:60950.9200
# Start epoch #53, learning rate for this epoch: [2.6121388032e-07]
# Train Epoch: 53 [200/800 (25.0%)]	Loss: 1.4351
# Train Epoch: 53 [400/800 (50.0%)]	Loss: 1.4502
# Train Epoch: 53 [600/800 (75.0%)]	Loss: 1.6545
# Train Epoch: 53 [800/800 (100.0%)]	Loss: 1.4072
# Done epoch #53, time for this epoch: 53.409666538238525s
# Epoch 53: loss: 1.4660, train accuracy: 61142.8075, valid accuracy:60941.8850
# Start epoch #54, learning rate for this epoch: [2.6121388032e-07]
# Train Epoch: 54 [200/800 (25.0%)]	Loss: 1.3973
# Train Epoch: 54 [400/800 (50.0%)]	Loss: 1.4754
# Train Epoch: 54 [600/800 (75.0%)]	Loss: 1.6357
# Train Epoch: 54 [800/800 (100.0%)]	Loss: 1.3568
# Done epoch #54, time for this epoch: 53.41815638542175s
# Epoch 54: loss: 1.4641, train accuracy: 61294.1750, valid accuracy:61112.4650
# Start epoch #55, learning rate for this epoch: [2.6121388032e-07]
# Train Epoch: 55 [200/800 (25.0%)]	Loss: 1.3716
# Train Epoch: 55 [400/800 (50.0%)]	Loss: 1.5179
# Train Epoch: 55 [600/800 (75.0%)]	Loss: 1.4159
# Train Epoch: 55 [800/800 (100.0%)]	Loss: 1.3073
# Done epoch #55, time for this epoch: 53.33170175552368s
# Epoch 55: loss: 1.4726, train accuracy: 61363.3850, valid accuracy:61204.5100
# Start epoch #56, learning rate for this epoch: [2.6121388032e-07]
# Train Epoch: 56 [200/800 (25.0%)]	Loss: 1.4375
# Train Epoch: 56 [400/800 (50.0%)]	Loss: 1.3699
# Train Epoch: 56 [600/800 (75.0%)]	Loss: 1.4567
# Train Epoch: 56 [800/800 (100.0%)]	Loss: 1.8768
# Done epoch #56, time for this epoch: 53.64716982841492s
# Epoch 56: loss: 1.4710, train accuracy: 61019.1588, valid accuracy:60712.1900
# Start epoch #57, learning rate for this epoch: [1.5672832819199997e-07]
# Train Epoch: 57 [200/800 (25.0%)]	Loss: 1.3205
# Train Epoch: 57 [400/800 (50.0%)]	Loss: 1.3198
# Train Epoch: 57 [600/800 (75.0%)]	Loss: 1.4517
# Train Epoch: 57 [800/800 (100.0%)]	Loss: 1.6518
# Done epoch #57, time for this epoch: 53.16663646697998s
# Epoch 57: loss: 1.4671, train accuracy: 60923.4187, valid accuracy:60789.4250
# Start epoch #58, learning rate for this epoch: [1.5672832819199997e-07]
# Train Epoch: 58 [200/800 (25.0%)]	Loss: 1.3462
# Train Epoch: 58 [400/800 (50.0%)]	Loss: 1.6166
# Train Epoch: 58 [600/800 (75.0%)]	Loss: 1.6049
# Train Epoch: 58 [800/800 (100.0%)]	Loss: 1.3296
# Done epoch #58, time for this epoch: 53.605448722839355s
# Epoch 58: loss: 1.4738, train accuracy: 61106.2125, valid accuracy:60994.8500
# Start epoch #59, learning rate for this epoch: [1.5672832819199997e-07]
# Train Epoch: 59 [200/800 (25.0%)]	Loss: 1.4780
# Train Epoch: 59 [400/800 (50.0%)]	Loss: 1.2580
# Train Epoch: 59 [600/800 (75.0%)]	Loss: 1.3603
# Train Epoch: 59 [800/800 (100.0%)]	Loss: 1.2962
# Done epoch #59, time for this epoch: 58.242146015167236s
# Epoch 59: loss: 1.4680, train accuracy: 60436.4500, valid accuracy:60296.7800
# Start epoch #60, learning rate for this epoch: [1.5672832819199997e-07]
# Train Epoch: 60 [200/800 (25.0%)]	Loss: 1.9490
# Train Epoch: 60 [400/800 (50.0%)]	Loss: 1.3346
# Train Epoch: 60 [600/800 (75.0%)]	Loss: 1.3905
# Train Epoch: 60 [800/800 (100.0%)]	Loss: 1.5260
# Done epoch #60, time for this epoch: 53.29293608665466s
# Epoch 60: loss: 1.4700, train accuracy: 60938.9125, valid accuracy:60652.5650
# Start epoch #61, learning rate for this epoch: [9.403699691519998e-08]
# Train Epoch: 61 [200/800 (25.0%)]	Loss: 1.3170
# Train Epoch: 61 [400/800 (50.0%)]	Loss: 1.3056
# Train Epoch: 61 [600/800 (75.0%)]	Loss: 1.4707
# Train Epoch: 61 [800/800 (100.0%)]	Loss: 1.7623
# Done epoch #61, time for this epoch: 53.54057788848877s
# Epoch 61: loss: 1.4753, train accuracy: 60717.6513, valid accuracy:60546.1400
# Start epoch #62, learning rate for this epoch: [9.403699691519998e-08]
# Train Epoch: 62 [200/800 (25.0%)]	Loss: 1.4822
# Train Epoch: 62 [400/800 (50.0%)]	Loss: 1.3852
# Train Epoch: 62 [600/800 (75.0%)]	Loss: 1.6299
# Train Epoch: 62 [800/800 (100.0%)]	Loss: 1.5455
# Done epoch #62, time for this epoch: 53.6090886592865s
# Epoch 62: loss: 1.4645, train accuracy: 61208.2637, valid accuracy:60939.5100
# Start epoch #63, learning rate for this epoch: [9.403699691519998e-08]
# Train Epoch: 63 [200/800 (25.0%)]	Loss: 1.3775
# Train Epoch: 63 [400/800 (50.0%)]	Loss: 1.3339
# Train Epoch: 63 [600/800 (75.0%)]	Loss: 1.4118
# Train Epoch: 63 [800/800 (100.0%)]	Loss: 1.2988
# Done epoch #63, time for this epoch: 53.36592411994934s
# Epoch 63: loss: 1.4688, train accuracy: 61051.8500, valid accuracy:60897.9200
# Start epoch #64, learning rate for this epoch: [9.403699691519998e-08]
# Train Epoch: 64 [200/800 (25.0%)]	Loss: 1.3661
# Train Epoch: 64 [400/800 (50.0%)]	Loss: 1.4207
# Train Epoch: 64 [600/800 (75.0%)]	Loss: 1.5731
# Train Epoch: 64 [800/800 (100.0%)]	Loss: 1.4476
# Done epoch #64, time for this epoch: 53.38197994232178s
# Epoch 64: loss: 1.4671, train accuracy: 61119.5987, valid accuracy:60863.4650
# Start epoch #65, learning rate for this epoch: [5.642219814911999e-08]
# Train Epoch: 65 [200/800 (25.0%)]	Loss: 1.4065
# Train Epoch: 65 [400/800 (50.0%)]	Loss: 1.6056
# Train Epoch: 65 [600/800 (75.0%)]	Loss: 1.3706
# Train Epoch: 65 [800/800 (100.0%)]	Loss: 1.3145
# Done epoch #65, time for this epoch: 53.44576573371887s
# Epoch 65: loss: 1.4685, train accuracy: 60588.6100, valid accuracy:60372.2350
# Start epoch #66, learning rate for this epoch: [5.642219814911999e-08]
# Train Epoch: 66 [200/800 (25.0%)]	Loss: 1.4641
# Train Epoch: 66 [400/800 (50.0%)]	Loss: 1.6068
# Train Epoch: 66 [600/800 (75.0%)]	Loss: 1.6046
# Train Epoch: 66 [800/800 (100.0%)]	Loss: 1.5133
# Done epoch #66, time for this epoch: 54.331289291381836s
# Epoch 66: loss: 1.4674, train accuracy: 61221.6350, valid accuracy:61137.7650
# Start epoch #67, learning rate for this epoch: [5.642219814911999e-08]
# Train Epoch: 67 [200/800 (25.0%)]	Loss: 1.7292
# Train Epoch: 67 [400/800 (50.0%)]	Loss: 1.4082
# Train Epoch: 67 [600/800 (75.0%)]	Loss: 1.6132
# Train Epoch: 67 [800/800 (100.0%)]	Loss: 1.4433
# Done epoch #67, time for this epoch: 55.89454698562622s
# Epoch 67: loss: 1.4699, train accuracy: 61026.7325, valid accuracy:60769.3200
# Start epoch #68, learning rate for this epoch: [5.642219814911999e-08]
# Train Epoch: 68 [200/800 (25.0%)]	Loss: 1.4702
# Train Epoch: 68 [400/800 (50.0%)]	Loss: 1.4068
# Train Epoch: 68 [600/800 (75.0%)]	Loss: 1.3757
# Train Epoch: 68 [800/800 (100.0%)]	Loss: 1.3081
# Done epoch #68, time for this epoch: 55.75067186355591s
# Epoch 68: loss: 1.4713, train accuracy: 60938.1900, valid accuracy:60738.5200
# Start epoch #69, learning rate for this epoch: [3.385331888947199e-08]
# Train Epoch: 69 [200/800 (25.0%)]	Loss: 1.5992
# Train Epoch: 69 [400/800 (50.0%)]	Loss: 1.2514
# Train Epoch: 69 [600/800 (75.0%)]	Loss: 1.3149
# Train Epoch: 69 [800/800 (100.0%)]	Loss: 1.3871
# Done epoch #69, time for this epoch: 53.25483989715576s
# Epoch 69: loss: 1.4695, train accuracy: 60948.5150, valid accuracy:60741.2600
# Start epoch #70, learning rate for this epoch: [3.385331888947199e-08]
# Train Epoch: 70 [200/800 (25.0%)]	Loss: 1.6021
# Train Epoch: 70 [400/800 (50.0%)]	Loss: 1.3530
# Train Epoch: 70 [600/800 (75.0%)]	Loss: 1.4269
# Train Epoch: 70 [800/800 (100.0%)]	Loss: 1.2930
# Done epoch #70, time for this epoch: 53.73097562789917s
# Epoch 70: loss: 1.4691, train accuracy: 61325.8938, valid accuracy:61236.4700
# Start epoch #71, learning rate for this epoch: [3.385331888947199e-08]
# Train Epoch: 71 [200/800 (25.0%)]	Loss: 1.6301
# Train Epoch: 71 [400/800 (50.0%)]	Loss: 1.4702
# Train Epoch: 71 [600/800 (75.0%)]	Loss: 1.3326
# Train Epoch: 71 [800/800 (100.0%)]	Loss: 1.8465
# Done epoch #71, time for this epoch: 53.55507707595825s
# Epoch 71: loss: 1.4730, train accuracy: 60510.0275, valid accuracy:60058.9050
# Start epoch #72, learning rate for this epoch: [3.385331888947199e-08]
# Train Epoch: 72 [200/800 (25.0%)]	Loss: 2.7767
# Train Epoch: 72 [400/800 (50.0%)]	Loss: 1.7343
# Train Epoch: 72 [600/800 (75.0%)]	Loss: 1.4078
# Train Epoch: 72 [800/800 (100.0%)]	Loss: 1.6307
# Done epoch #72, time for this epoch: 53.90589356422424s
# Epoch 72: loss: 1.4707, train accuracy: 59330.1350, valid accuracy:59120.9950
# Start epoch #73, learning rate for this epoch: [2.0311991333683194e-08]
# Train Epoch: 73 [200/800 (25.0%)]	Loss: 1.7360
# Train Epoch: 73 [400/800 (50.0%)]	Loss: 1.4181
# Train Epoch: 73 [600/800 (75.0%)]	Loss: 1.5781
# Train Epoch: 73 [800/800 (100.0%)]	Loss: 1.4375
# Done epoch #73, time for this epoch: 53.85522413253784s
# Epoch 73: loss: 1.4710, train accuracy: 60503.5287, valid accuracy:60155.4400
# Start epoch #74, learning rate for this epoch: [2.0311991333683194e-08]
# Train Epoch: 74 [200/800 (25.0%)]	Loss: 1.4456
# Train Epoch: 74 [400/800 (50.0%)]	Loss: 1.3052
# Train Epoch: 74 [600/800 (75.0%)]	Loss: 1.6840
# Train Epoch: 74 [800/800 (100.0%)]	Loss: 1.5998
# Done epoch #74, time for this epoch: 53.9646053314209s
# Epoch 74: loss: 1.4654, train accuracy: 61182.1837, valid accuracy:60960.9750
# Start epoch #75, learning rate for this epoch: [2.0311991333683194e-08]
# Train Epoch: 75 [200/800 (25.0%)]	Loss: 1.4490
# Train Epoch: 75 [400/800 (50.0%)]	Loss: 1.4857
# Train Epoch: 75 [600/800 (75.0%)]	Loss: 1.2999
# Train Epoch: 75 [800/800 (100.0%)]	Loss: 1.3952
# Done epoch #75, time for this epoch: 53.73385572433472s
# Epoch 75: loss: 1.4694, train accuracy: 61472.3213, valid accuracy:61302.1600
# Start epoch #76, learning rate for this epoch: [2.0311991333683194e-08]
# Train Epoch: 76 [200/800 (25.0%)]	Loss: 1.3446
# Train Epoch: 76 [400/800 (50.0%)]	Loss: 1.3377
# Train Epoch: 76 [600/800 (75.0%)]	Loss: 1.6462
# Train Epoch: 76 [800/800 (100.0%)]	Loss: 1.3739
# Done epoch #76, time for this epoch: 53.65135645866394s
# Epoch 76: loss: 1.4700, train accuracy: 61195.9400, valid accuracy:61045.5250
# Start epoch #77, learning rate for this epoch: [1.2187194800209916e-08]
# Train Epoch: 77 [200/800 (25.0%)]	Loss: 1.5502
# Train Epoch: 77 [400/800 (50.0%)]	Loss: 1.4907
# Train Epoch: 77 [600/800 (75.0%)]	Loss: 1.5975
# Train Epoch: 77 [800/800 (100.0%)]	Loss: 1.3547
# Done epoch #77, time for this epoch: 53.809937953948975s
# Epoch 77: loss: 1.4682, train accuracy: 61034.7175, valid accuracy:60899.7150
# Start epoch #78, learning rate for this epoch: [1.2187194800209916e-08]
# Train Epoch: 78 [200/800 (25.0%)]	Loss: 1.2677
# Train Epoch: 78 [400/800 (50.0%)]	Loss: 1.7903
# Train Epoch: 78 [600/800 (75.0%)]	Loss: 1.4185
# Train Epoch: 78 [800/800 (100.0%)]	Loss: 1.4112
# Done epoch #78, time for this epoch: 53.31625199317932s
# Epoch 78: loss: 1.4681, train accuracy: 61295.8225, valid accuracy:61229.9100
# Start epoch #79, learning rate for this epoch: [1.2187194800209916e-08]
# Train Epoch: 79 [200/800 (25.0%)]	Loss: 1.3040
# Train Epoch: 79 [400/800 (50.0%)]	Loss: 1.2855
# Train Epoch: 79 [600/800 (75.0%)]	Loss: 1.5020
# Train Epoch: 79 [800/800 (100.0%)]	Loss: 1.5066
# Done epoch #79, time for this epoch: 53.40028953552246s
# Epoch 79: loss: 1.4707, train accuracy: 60470.2063, valid accuracy:60151.8700
# Start epoch #80, learning rate for this epoch: [1.2187194800209916e-08]
# Train Epoch: 80 [200/800 (25.0%)]	Loss: 1.3777
# Train Epoch: 80 [400/800 (50.0%)]	Loss: 1.9044
# Train Epoch: 80 [600/800 (75.0%)]	Loss: 1.3460
# Train Epoch: 80 [800/800 (100.0%)]	Loss: 1.5009
# Done epoch #80, time for this epoch: 53.289576292037964s
# Epoch 80: loss: 1.4724, train accuracy: 61387.0312, valid accuracy:61250.6050
# Start epoch #81, learning rate for this epoch: [7.31231688012595e-09]
# Train Epoch: 81 [200/800 (25.0%)]	Loss: 1.3753
# Train Epoch: 81 [400/800 (50.0%)]	Loss: 1.5815
# Train Epoch: 81 [600/800 (75.0%)]	Loss: 1.4365
# Train Epoch: 81 [800/800 (100.0%)]	Loss: 1.3818
# Done epoch #81, time for this epoch: 53.61288237571716s
# Epoch 81: loss: 1.4712, train accuracy: 61074.7237, valid accuracy:60903.3850
# Start epoch #82, learning rate for this epoch: [7.31231688012595e-09]
# Train Epoch: 82 [200/800 (25.0%)]	Loss: 1.3751
# Train Epoch: 82 [400/800 (50.0%)]	Loss: 1.6016
# Train Epoch: 82 [600/800 (75.0%)]	Loss: 1.4487
# Train Epoch: 82 [800/800 (100.0%)]	Loss: 1.4028
# Done epoch #82, time for this epoch: 53.57444977760315s
# Epoch 82: loss: 1.4707, train accuracy: 60386.1038, valid accuracy:60254.5850
# Start epoch #83, learning rate for this epoch: [7.31231688012595e-09]
# Train Epoch: 83 [200/800 (25.0%)]	Loss: 1.5958
# Train Epoch: 83 [400/800 (50.0%)]	Loss: 1.4905
# Train Epoch: 83 [600/800 (75.0%)]	Loss: 1.3969
# Train Epoch: 83 [800/800 (100.0%)]	Loss: 1.4077
# Done epoch #83, time for this epoch: 53.4776713848114s
# Epoch 83: loss: 1.4711, train accuracy: 60881.6925, valid accuracy:60664.6750
# Start epoch #84, learning rate for this epoch: [7.31231688012595e-09]
# Train Epoch: 84 [200/800 (25.0%)]	Loss: 1.2286
# Train Epoch: 84 [400/800 (50.0%)]	Loss: 1.3110
# Train Epoch: 84 [600/800 (75.0%)]	Loss: 1.6099
# Train Epoch: 84 [800/800 (100.0%)]	Loss: 1.4198
# Done epoch #84, time for this epoch: 53.18489408493042s
# Epoch 84: loss: 1.4735, train accuracy: 61334.2625, valid accuracy:61237.4350
# Start epoch #85, learning rate for this epoch: [4.38739012807557e-09]
# Train Epoch: 85 [200/800 (25.0%)]	Loss: 1.6187
# Train Epoch: 85 [400/800 (50.0%)]	Loss: 1.3485
# Train Epoch: 85 [600/800 (75.0%)]	Loss: 1.3891
# Train Epoch: 85 [800/800 (100.0%)]	Loss: 1.4396
# Done epoch #85, time for this epoch: 53.48100662231445s
# Epoch 85: loss: 1.4715, train accuracy: 61162.5238, valid accuracy:60938.5850
# Start epoch #86, learning rate for this epoch: [4.38739012807557e-09]
# Train Epoch: 86 [200/800 (25.0%)]	Loss: 1.4845
# Train Epoch: 86 [400/800 (50.0%)]	Loss: 1.4010
# Train Epoch: 86 [600/800 (75.0%)]	Loss: 1.5328
# Train Epoch: 86 [800/800 (100.0%)]	Loss: 1.7065
# Done epoch #86, time for this epoch: 53.651817321777344s
# Epoch 86: loss: 1.4688, train accuracy: 60288.6687, valid accuracy:60210.0400
# Start epoch #87, learning rate for this epoch: [4.38739012807557e-09]
# Train Epoch: 87 [200/800 (25.0%)]	Loss: 1.3770
# Train Epoch: 87 [400/800 (50.0%)]	Loss: 1.5479
# Train Epoch: 87 [600/800 (75.0%)]	Loss: 1.3458
# Train Epoch: 87 [800/800 (100.0%)]	Loss: 1.4507
# Done epoch #87, time for this epoch: 53.473143339157104s
# Epoch 87: loss: 1.4665, train accuracy: 61570.1762, valid accuracy:61479.4900
# Start epoch #88, learning rate for this epoch: [4.38739012807557e-09]
# Train Epoch: 88 [200/800 (25.0%)]	Loss: 1.2875
# Train Epoch: 88 [400/800 (50.0%)]	Loss: 1.3168
# Train Epoch: 88 [600/800 (75.0%)]	Loss: 1.1926
# Train Epoch: 88 [800/800 (100.0%)]	Loss: 1.6634
# Done epoch #88, time for this epoch: 54.85655736923218s
# Epoch 88: loss: 1.4706, train accuracy: 60878.2712, valid accuracy:60754.1050
# Start epoch #89, learning rate for this epoch: [2.6324340768453418e-09]
# Train Epoch: 89 [200/800 (25.0%)]	Loss: 1.3660
# Train Epoch: 89 [400/800 (50.0%)]	Loss: 1.4751
# Train Epoch: 89 [600/800 (75.0%)]	Loss: 1.5341
# Train Epoch: 89 [800/800 (100.0%)]	Loss: 1.2893
# Done epoch #89, time for this epoch: 55.317254304885864s
# Epoch 89: loss: 1.4694, train accuracy: 60744.0775, valid accuracy:60555.9100
# Start epoch #90, learning rate for this epoch: [2.6324340768453418e-09]
# Train Epoch: 90 [200/800 (25.0%)]	Loss: 1.5581
# Train Epoch: 90 [400/800 (50.0%)]	Loss: 1.3780
# Train Epoch: 90 [600/800 (75.0%)]	Loss: 1.6280
# Train Epoch: 90 [800/800 (100.0%)]	Loss: 1.5169
# Done epoch #90, time for this epoch: 53.39327573776245s
# Epoch 90: loss: 1.4599, train accuracy: 61016.7363, valid accuracy:60950.5500
# Start epoch #91, learning rate for this epoch: [2.6324340768453418e-09]
# Train Epoch: 91 [200/800 (25.0%)]	Loss: 1.1943
# Train Epoch: 91 [400/800 (50.0%)]	Loss: 1.3532
# Train Epoch: 91 [600/800 (75.0%)]	Loss: 1.4438
# Train Epoch: 91 [800/800 (100.0%)]	Loss: 1.4600
# Done epoch #91, time for this epoch: 53.45095944404602s
# Epoch 91: loss: 1.4723, train accuracy: 60493.9088, valid accuracy:60242.7100
# Start epoch #92, learning rate for this epoch: [2.6324340768453418e-09]
# Train Epoch: 92 [200/800 (25.0%)]	Loss: 1.5472
# Train Epoch: 92 [400/800 (50.0%)]	Loss: 1.5026
# Train Epoch: 92 [600/800 (75.0%)]	Loss: 1.5140
# Train Epoch: 92 [800/800 (100.0%)]	Loss: 1.4167
# Done epoch #92, time for this epoch: 53.3282527923584s
# Epoch 92: loss: 1.4704, train accuracy: 60873.7538, valid accuracy:60619.2500
# Start epoch #93, learning rate for this epoch: [1.579460446107205e-09]
# Train Epoch: 93 [200/800 (25.0%)]	Loss: 1.3799
# Train Epoch: 93 [400/800 (50.0%)]	Loss: 1.3255
# Train Epoch: 93 [600/800 (75.0%)]	Loss: 1.3788
# Train Epoch: 93 [800/800 (100.0%)]	Loss: 1.3761
# Done epoch #93, time for this epoch: 53.6641309261322s
# Epoch 93: loss: 1.4674, train accuracy: 61249.5100, valid accuracy:61104.7800
# Start epoch #94, learning rate for this epoch: [1.579460446107205e-09]
# Train Epoch: 94 [200/800 (25.0%)]	Loss: 1.6185
# Train Epoch: 94 [400/800 (50.0%)]	Loss: 1.7116
# Train Epoch: 94 [600/800 (75.0%)]	Loss: 1.3634
# Train Epoch: 94 [800/800 (100.0%)]	Loss: 1.4625
# Done epoch #94, time for this epoch: 53.3622407913208s
# Epoch 94: loss: 1.4738, train accuracy: 60707.6100, valid accuracy:60476.6400
# Start epoch #95, learning rate for this epoch: [1.579460446107205e-09]
# Train Epoch: 95 [200/800 (25.0%)]	Loss: 1.4246
# Train Epoch: 95 [400/800 (50.0%)]	Loss: 1.3238
# Train Epoch: 95 [600/800 (75.0%)]	Loss: 1.4614
# Train Epoch: 95 [800/800 (100.0%)]	Loss: 1.5083
# Done epoch #95, time for this epoch: 53.3097722530365s
# Epoch 95: loss: 1.4723, train accuracy: 60928.6038, valid accuracy:60732.5150
# Start epoch #96, learning rate for this epoch: [1.579460446107205e-09]
# Train Epoch: 96 [200/800 (25.0%)]	Loss: 1.2631
# Train Epoch: 96 [400/800 (50.0%)]	Loss: 1.3610
# Train Epoch: 96 [600/800 (75.0%)]	Loss: 1.6461
# Train Epoch: 96 [800/800 (100.0%)]	Loss: 1.5731
# Done epoch #96, time for this epoch: 53.3537323474884s
# Epoch 96: loss: 1.4640, train accuracy: 61274.9488, valid accuracy:61155.6750
# Start epoch #97, learning rate for this epoch: [9.47676267664323e-10]
# Train Epoch: 97 [200/800 (25.0%)]	Loss: 1.5139
# Train Epoch: 97 [400/800 (50.0%)]	Loss: 1.5249
# Train Epoch: 97 [600/800 (75.0%)]	Loss: 1.3982
# Train Epoch: 97 [800/800 (100.0%)]	Loss: 1.5342
# Done epoch #97, time for this epoch: 53.2968213558197s
# Epoch 97: loss: 1.4708, train accuracy: 61435.9488, valid accuracy:61065.7400
# Start epoch #98, learning rate for this epoch: [9.47676267664323e-10]
# Train Epoch: 98 [200/800 (25.0%)]	Loss: 1.8692
# Train Epoch: 98 [400/800 (50.0%)]	Loss: 1.3464
# Train Epoch: 98 [600/800 (75.0%)]	Loss: 1.6753
# Train Epoch: 98 [800/800 (100.0%)]	Loss: 1.4261
# Done epoch #98, time for this epoch: 53.968101501464844s
# Epoch 98: loss: 1.4732, train accuracy: 60790.1813, valid accuracy:60422.4900
# Start epoch #99, learning rate for this epoch: [9.47676267664323e-10]
# Train Epoch: 99 [200/800 (25.0%)]	Loss: 1.3545
# Train Epoch: 99 [400/800 (50.0%)]	Loss: 1.4594
# Train Epoch: 99 [600/800 (75.0%)]	Loss: 1.3436
# Train Epoch: 99 [800/800 (100.0%)]	Loss: 1.4339
# Done epoch #99, time for this epoch: 53.589853286743164s
# Epoch 99: loss: 1.4707, train accuracy: 61240.3887, valid accuracy:61145.9400
# Start epoch #100, learning rate for this epoch: [9.47676267664323e-10]
# Train Epoch: 100 [200/800 (25.0%)]	Loss: 1.3784
# Train Epoch: 100 [400/800 (50.0%)]	Loss: 1.3570
# Train Epoch: 100 [600/800 (75.0%)]	Loss: 1.2941
# Train Epoch: 100 [800/800 (100.0%)]	Loss: 1.3547
# Done epoch #100, time for this epoch: 53.42463827133179s
# Epoch 100: loss: 1.4729, train accuracy: 60284.3438, valid accuracy:60187.0100

# %% [markdown]
# # Plot the learning cure

# %%
checkpoint_path = '/kaggle/working/unet_model.pth'
loaded_model, loaded_optimizer = load_model(model, optimizer, checkpoint_path)

# %%
plt.rcParams['figure.dpi'] = 90
plt.rcParams['figure.figsize'] = (6, 4)
epochs_array = range(epochs)

# %%
# Plot Training and Test loss
plt.plot(epochs_array, train_loss_array, 'g', label='Training loss')
# plt.plot(epochs_array, test_loss_array, 'b', label='Test loss')
plt.title('Training and Test loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# # Visualize results

# %%
for i, (data, label) in enumerate(train_dataloader):
    img = data
    mask = label
    break

# %%
fig, arr = plt.subplots(4, 3, figsize=(16, 12))
arr[0][0].set_title('Image')
arr[0][1].set_title('Segmentation')
arr[0][2].set_title('Predict')

model.eval()
with torch.no_grad():
    predict = model(img)

for i in range(4):
    arr[i][0].imshow(img[i].permute(1, 2, 0));

    arr[i][1].imshow(F.one_hot(mask[i]).float())

    arr[i][2].imshow(F.one_hot(torch.argmax(predict[i], 0).cpu()).float())

# %%
test_transform = Compose([Resize((256, 256), interpolation=InterpolationMode.BILINEAR),
                     PILToTensor()])

# %%
class UNetTestDataClass(Dataset):
    def __init__(self, images_path, transform):
        super(UNetTestDataClass, self).__init__()

        images_list = os.listdir(images_path)
        images_list = [images_path+i for i in images_list]

        self.images_list = images_list
        self.transform = transform

    def __getitem__(self, index):
        img_path = self.images_list[index]
        data = Image.open(img_path)
        h = data.size[1]
        w = data.size[0]
        data = self.transform(data) / 255
        return data, img_path, h, w

    def __len__(self):
        return len(self.images_list)

# %%
path = '/kaggle/input/bkai-igh-neopolyp/test/test/'
unet_test_dataset = UNetTestDataClass(path, test_transform)
test_dataloader = DataLoader(unet_test_dataset, batch_size=8, shuffle=True)

# %%
for i, (data, path, h, w) in enumerate(test_dataloader):
    img = data
    break

# %%
fig, arr = plt.subplots(5, 2, figsize=(16, 12))
arr[0][0].set_title('Image');
arr[0][1].set_title('Predict');

model.eval()
with torch.no_grad():
    predict = model(img)

for i in range(5):
    arr[i][0].imshow(img[i].permute(1, 2, 0));
    arr[i][1].imshow(F.one_hot(torch.argmax(predict[i], 0).cpu()).float())

# %%
model.eval()

output_dir = "/kaggle/working/predicted_masks"  # Use /kaggle/working/ instead of /kaggle/input/
if not os.path.isdir(output_dir):
    os.mkdir(output_dir)

for _, (img, path, H, W) in enumerate(test_dataloader):
    a = path
    b = img
    h = H
    w = W

    with torch.no_grad():
        predicted_mask = model(b)

    for i in range(len(a)):
        image_id = a[i].split('/')[-1].split('.')[0]
        filename = image_id + ".png"
        mask2img = Resize((h[i].item(), w[i].item()), interpolation=InterpolationMode.NEAREST)(ToPILImage()(F.one_hot(torch.argmax(predicted_mask[i], 0)).permute(2, 0, 1).float()))

        mask2img.save(os.path.join(output_dir, filename))

# %%
def rle_to_string(runs):
    return ' '.join(str(x) for x in runs)

def rle_encode_one_mask(mask):
    pixels = mask.flatten()
    pixels[pixels > 0] = 255
    use_padding = False
    if pixels[0] or pixels[-1]:
        use_padding = True
        pixel_padded = np.zeros([len(pixels) + 2], dtype=pixels.dtype)
        pixel_padded[1:-1] = pixels
        pixels = pixel_padded

    rle = np.where(pixels[1:] != pixels[:-1])[0] + 2
    if use_padding:
        rle = rle - 1
    rle[1::2] = rle[1::2] - rle[:-1:2]
    return rle_to_string(rle)

def mask2string(dir):
    ## mask --> string
    strings = []
    ids = []
    ws, hs = [[] for i in range(2)]
    for image_id in os.listdir(dir):
        id = image_id.split('.')[0]
        path = os.path.join(dir, image_id)
        print(path)
        img = cv2.imread(path)[:,:,::-1]
        h, w = img.shape[0], img.shape[1]
        for channel in range(2):
            ws.append(w)
            hs.append(h)
            ids.append(f'{id}_{channel}')
            string = rle_encode_one_mask(img[:,:,channel])
            strings.append(string)
    r = {
        'ids': ids,
        'strings': strings,
    }
    return r


MASK_DIR_PATH = '/kaggle/working/predicted_masks' # change this to the path to your output mask folder
dir = MASK_DIR_PATH
res = mask2string(dir)
df = pd.DataFrame(columns=['Id', 'Expected'])
df['Id'] = res['ids']
df['Expected'] = res['strings']
df.to_csv(r'output.csv', index=False)
# Out:
# /kaggle/working/predicted_masks/1002ec4a1fe748f3085f1ce88cbdf366.png
# /kaggle/working/predicted_masks/cc5cfd263f1f90be28799235026b3550.png
# /kaggle/working/predicted_masks/f13dd311a65d2b46d0a6085835c525af.png
# /kaggle/working/predicted_masks/aafac813fe3ccba3e032dd2948a80c64.png
# /kaggle/working/predicted_masks/1531871f2fd85a04faeeb2b535797395.png
# /kaggle/working/predicted_masks/f62f215f0da4ad3a7ab8df9da7386835.png
# /kaggle/working/predicted_masks/c193ac8d551c149b60f2965341caf528.png
# /kaggle/working/predicted_masks/63b8318ecf467d7ad048df39beb17636.png
# /kaggle/working/predicted_masks/e9082ea2c193ac8d551c149b60f29653.png
# /kaggle/working/predicted_masks/314fe384eb2ba3adfda6c1899fdc9837.png
# /kaggle/working/predicted_masks/87133b51209db6dcdda5cc8a788edaeb.png
# /kaggle/working/predicted_masks/cbb2a365b5574868eb60861ee1ff0b8a.png
# /kaggle/working/predicted_masks/c695325ded465efde988dfb96d081533.png
# /kaggle/working/predicted_masks/26679bff55177a34fc01019eec999fd8.png
# /kaggle/working/predicted_masks/c41545ba55aadaa77712a48e11d579d9.png
# /kaggle/working/predicted_masks/cb2eb1ef57af2ed9fbb63b28163a7459.png
# /kaggle/working/predicted_masks/88e16d4ca6160127cd1d5ff99c267599.png
# /kaggle/working/predicted_masks/ea42b4eebc9e5a87e443434ac60af150.png
# /kaggle/working/predicted_masks/782707d7c359e27888daefee82519763.png
# /kaggle/working/predicted_masks/2cd066b9fdbc3bbc04a3afe1f119f21b.png
# /kaggle/working/predicted_masks/2d9e593b6be1ac29adbe86f03d900fd1.png
# /kaggle/working/predicted_masks/9fc7330398846f67b5df7cdf3f33c3ca.png
# /kaggle/working/predicted_masks/c22268d4b4ef4d95ceea11957998906d.png
# /kaggle/working/predicted_masks/a15fc656702fa602bb3c7abacdbd7e6a.png
# /kaggle/working/predicted_masks/1db239dda50f954ba59c7de13a35276a.png
# /kaggle/working/predicted_masks/6f4d4987ea3b4bae5672a230194c5a08.png
# /kaggle/working/predicted_masks/dc70626ab4ec3d46e602b296cc5cfd26.png
# /kaggle/working/predicted_masks/3657e4314fe384eb2ba3adfda6c1899f.png
# /kaggle/working/predicted_masks/df8e26031fbb5e52c41545ba55aadaa7.png
# /kaggle/working/predicted_masks/39dda50f954ba59c7de13a35276a4764.png
# /kaggle/working/predicted_masks/cf464aa36bf7c09a3bb0e5ca159410b9.png
# /kaggle/working/predicted_masks/41ed86e58224cb76a67d4dcf9596154e.png
# /kaggle/working/predicted_masks/a48847ae8395e56a6d9ba9d45c3dbc69.png
# /kaggle/working/predicted_masks/ff55177a34fc01019eec999fd84e679b.png
# /kaggle/working/predicted_masks/1b62f15ec83b97bb11e8e0c4416c1931.png
# /kaggle/working/predicted_masks/e8bfb905b78a91391adc0bb223c4eaf3.png
# /kaggle/working/predicted_masks/998906d3694abb47953b0e4909384b57.png
# /kaggle/working/predicted_masks/fcd6da15fc656702fa602bb3c7abacdb.png
# /kaggle/working/predicted_masks/4fda8daadc8dd23ae214d84b5dec33fd.png
# /kaggle/working/predicted_masks/50534bca540e24f489284b8e6953ad88.png
# /kaggle/working/predicted_masks/1c0e9082ea2c193ac8d551c149b60f29.png
# /kaggle/working/predicted_masks/3c692195f853af7f8a4df1ec859759b7.png
# /kaggle/working/predicted_masks/6231002ec4a1fe748f3085f1ce88cbdf.png
# /kaggle/working/predicted_masks/7f32574d6c748c41743c6c08a1d1ad8f.png
# /kaggle/working/predicted_masks/80c643782707d7c359e27888daefee82.png
# /kaggle/working/predicted_masks/5c1346e62522325c1b9c4fc9cbe1eca1.png
# /kaggle/working/predicted_masks/0a0317371a966bf4b3466463a3c64db1.png
# /kaggle/working/predicted_masks/7cb2eb1ef57af2ed9fbb63b28163a745.png
# /kaggle/working/predicted_masks/8fa8625605da2023387fd56c04414eaa.png
# /kaggle/working/predicted_masks/7330398846f67b5df7cdf3f33c3ca4d5.png
# /kaggle/working/predicted_masks/b21960c94b0aab4c024a573c692195f8.png
# /kaggle/working/predicted_masks/d694539ef2424a9218697283baa3657e.png
# /kaggle/working/predicted_masks/343f27ebc5d92b9076135d76d0bbd4ce.png
# /kaggle/working/predicted_masks/5a51625559c7e610b1531871f2fd85a0.png
# /kaggle/working/predicted_masks/0fca6a4248a41e8db8b4ed633b456aaa.png
# /kaggle/working/predicted_masks/72d9e593b6be1ac29adbe86f03d900fd.png
# /kaggle/working/predicted_masks/05b78a91391adc0bb223c4eaf3372eae.png
# /kaggle/working/predicted_masks/710d568df17586ad8f3297c819c90895.png
# /kaggle/working/predicted_masks/e56a6d9ba9d45c3dbc695325ded465ef.png
# /kaggle/working/predicted_masks/395e56a6d9ba9d45c3dbc695325ded46.png
# /kaggle/working/predicted_masks/4e8bfb905b78a91391adc0bb223c4eaf.png
# /kaggle/working/predicted_masks/fb905b78a91391adc0bb223c4eaf3372.png
# /kaggle/working/predicted_masks/85a04faeeb2b535797395305af926a6f.png
# /kaggle/working/predicted_masks/285e26c90e1797c77826f9a7021bab9f.png
# /kaggle/working/predicted_masks/5beb48f0be11d0309d1dff09b8405734.png
# /kaggle/working/predicted_masks/c5a0808bee60b246359c68c836f843dc.png
# /kaggle/working/predicted_masks/cf6644589e532a9ee954f81faedbce39.png
# /kaggle/working/predicted_masks/6d3694abb47953b0e4909384b57bb6a0.png
# /kaggle/working/predicted_masks/bec33b5e3d68f9d4c331587f9b9d49e2.png
# /kaggle/working/predicted_masks/67d4dcf9596154efb7cef748d9cbd617.png
# /kaggle/working/predicted_masks/3c3ca4d5060a633a8d5b2b2b55157b77.png
# /kaggle/working/predicted_masks/6b83ef461c2a337948a41964c1d4f50a.png
# /kaggle/working/predicted_masks/e2cd066b9fdbc3bbc04a3afe1f119f21.png
# /kaggle/working/predicted_masks/4ef4d95ceea11957998906d3694abb47.png
# /kaggle/working/predicted_masks/677a6b1f2c6d40b3bbba8f6c704801b3.png
# /kaggle/working/predicted_masks/cb1b387133b51209db6dcdda5cc8a788.png
# /kaggle/working/predicted_masks/a51625559c7e610b1531871f2fd85a04.png
# /kaggle/working/predicted_masks/2a365b5574868eb60861ee1ff0b8a4f6.png
# /kaggle/working/predicted_masks/eecd70ebce6347c491b37c8c2e5a64a8.png
# /kaggle/working/predicted_masks/4f437f0019f7e6af7d7147763bdfb928.png
# /kaggle/working/predicted_masks/98da48d679d7c7c8d3d96fb2b87fbbcf.png
# /kaggle/working/predicted_masks/8954bb13d3727c7e5e1069646f2f0bb8.png
# /kaggle/working/predicted_masks/05734fbeedd0f9da760db74a29abdb04.png
# /kaggle/working/predicted_masks/d6bf62f215f0da4ad3a7ab8df9da7386.png
# /kaggle/working/predicted_masks/4417fda8019410b1fcf0625f608b4ce9.png
# /kaggle/working/predicted_masks/425b976973f13dd311a65d2b46d0a608.png
# /kaggle/working/predicted_masks/82ea2c193ac8d551c149b60f2965341c.png
# /kaggle/working/predicted_masks/a6e51d077bad31c8c5f54ffaa27a6235.png
# /kaggle/working/predicted_masks/aeeb2b535797395305af926a6f23c5d6.png
# /kaggle/working/predicted_masks/39d6aad6bb0170a40ed32deef71fbe08.png
# /kaggle/working/predicted_masks/45b21960c94b0aab4c024a573c692195.png
# /kaggle/working/predicted_masks/30c2f4fc276ed9f178dc2f4af6266509.png
# /kaggle/working/predicted_masks/0619ebebe9e9c9d00a4262b4fe4a5a95.png
# /kaggle/working/predicted_masks/7cdf3f33c3ca4d5060a633a8d5b2b2b5.png
# /kaggle/working/predicted_masks/71f2fd85a04faeeb2b535797395305af.png
# /kaggle/working/predicted_masks/f14e1e0ae936de314f2d95e6c487ffa6.png
# /kaggle/working/predicted_masks/af35b65bd9ea42cfcfedb5eb2a0e4b50.png
# /kaggle/working/predicted_masks/7936140a2d5fc1443c4e445927738677.png
# /kaggle/working/predicted_masks/5b21960c94b0aab4c024a573c692195f.png
# /kaggle/working/predicted_masks/be86f03d900fd197cd955fa095f97845.png
# /kaggle/working/predicted_masks/0398846f67b5df7cdf3f33c3ca4d5060.png
# /kaggle/working/predicted_masks/7ad1cf2eb9d32a3dc907950289e976c7.png
# /kaggle/working/predicted_masks/ca4d5060a633a8d5b2b2b55157b7781e.png
# /kaggle/working/predicted_masks/461c2a337948a41964c1d4f50a5f3601.png
# /kaggle/working/predicted_masks/6679bff55177a34fc01019eec999fd84.png
# /kaggle/working/predicted_masks/5e8f14e1e0ae936de314f2d95e6c487f.png
# /kaggle/working/predicted_masks/268d4b4ef4d95ceea11957998906d369.png
# /kaggle/working/predicted_masks/6240619ebebe9e9c9d00a4262b4fe4a5.png
# /kaggle/working/predicted_masks/eff05dec1eb3a70b145a7d8d3b6c0ed7.png
# /kaggle/working/predicted_masks/c4be73749a0d21db70dd094a7f32574d.png
# /kaggle/working/predicted_masks/1ad4f13ccf1f4b331a412fc44655fb51.png
# /kaggle/working/predicted_masks/1209db6dcdda5cc8a788edaeb6aa460a.png
# /kaggle/working/predicted_masks/4c1711b62f15ec83b97bb11e8e0c4416.png
# /kaggle/working/predicted_masks/e1797c77826f9a7021bab9fc73303988.png
# /kaggle/working/predicted_masks/dc0bb223c4eaf3372eae567c94ea04c6.png
# /kaggle/working/predicted_masks/df366e057db382b8564872a27301a654.png
# /kaggle/working/predicted_masks/625559c7e610b1531871f2fd85a04fae.png
# /kaggle/working/predicted_masks/6ddca6ee1af35b65bd9ea42cfcfedb5e.png
# /kaggle/working/predicted_masks/66e057db382b8564872a27301a654864.png
# /kaggle/working/predicted_masks/0626ab4ec3d46e602b296cc5cfd263f1.png
# /kaggle/working/predicted_masks/626650908b1cb932a767bf5487ced51b.png
# /kaggle/working/predicted_masks/ff05dec1eb3a70b145a7d8d3b6c0ed75.png
# /kaggle/working/predicted_masks/e3c84417fda8019410b1fcf0625f608b.png
# /kaggle/working/predicted_masks/f8e5ad89d2844837f2a0f1536ad3f6a5.png
# /kaggle/working/predicted_masks/019410b1fcf0625f608b4ce97629ab55.png
# /kaggle/working/predicted_masks/e73749a0d21db70dd094a7f32574d6c7.png
# /kaggle/working/predicted_masks/e5e8f14e1e0ae936de314f2d95e6c487.png
# /kaggle/working/predicted_masks/ad43fe2cd066b9fdbc3bbc04a3afe1f1.png
# /kaggle/working/predicted_masks/dd094a7f32574d6c748c41743c6c08a1.png
# /kaggle/working/predicted_masks/0a5f3601ad4f13ccf1f4b331a412fc44.png
# /kaggle/working/predicted_masks/4e2a6e51d077bad31c8c5f54ffaa27a6.png
# /kaggle/working/predicted_masks/5026b3550534bca540e24f489284b8e6.png
# /kaggle/working/predicted_masks/936de314f2d95e6c487ffa651b477422.png
# /kaggle/working/predicted_masks/633a8d5b2b2b55157b7781e2c706c75c.png
# /kaggle/working/predicted_masks/a6a4248a41e8db8b4ed633b456aaafac.png
# /kaggle/working/predicted_masks/97e1c0e9082ea2c193ac8d551c149b60.png
# /kaggle/working/predicted_masks/8395e56a6d9ba9d45c3dbc695325ded4.png
# /kaggle/working/predicted_masks/e4a17af18f72c8e6166a915669c99390.png
# /kaggle/working/predicted_masks/7af2ed9fbb63b28163a745959c039830.png
# /kaggle/working/predicted_masks/7f0019f7e6af7d7147763bdfb928d788.png
# /kaggle/working/predicted_masks/692195f853af7f8a4df1ec859759b7c8.png
# /kaggle/working/predicted_masks/80cae6daedd989517cb8041ed86e5822.png
# /kaggle/working/predicted_masks/5664c1711b62f15ec83b97bb11e8e0c4.png
# /kaggle/working/predicted_masks/8b8ec74baddc22268d4b4ef4d95ceea1.png
# /kaggle/working/predicted_masks/9632a3c6f7f7fb2a643f15bd0249ddcc.png
# /kaggle/working/predicted_masks/7b5df7cdf3f33c3ca4d5060a633a8d5b.png
# /kaggle/working/predicted_masks/d5060a633a8d5b2b2b55157b7781e2c7.png
# /kaggle/working/predicted_masks/0af3feff05dec1eb3a70b145a7d8d3b6.png
# /kaggle/working/predicted_masks/c7e610b1531871f2fd85a04faeeb2b53.png
# /kaggle/working/predicted_masks/f8e26031fbb5e52c41545ba55aadaa77.png
# /kaggle/working/predicted_masks/a9d45c3dbc695325ded465efde988dfb.png
# /kaggle/working/predicted_masks/afe1f119f21b248d152b672ab3492fc6.png
# /kaggle/working/predicted_masks/eb1ef57af2ed9fbb63b28163a745959c.png
# /kaggle/working/predicted_masks/4ca6160127cd1d5ff99c267599fc487b.png
# /kaggle/working/predicted_masks/3f33c3ca4d5060a633a8d5b2b2b55157.png
# /kaggle/working/predicted_masks/3b8318ecf467d7ad048df39beb176363.png
# /kaggle/working/predicted_masks/e19769fa2d37d32780fd497e1c0e9082.png
# /kaggle/working/predicted_masks/60b246359c68c836f843dcf41f4dce3c.png
# /kaggle/working/predicted_masks/7fda8019410b1fcf0625f608b4ce9762.png
# /kaggle/working/predicted_masks/54ba59c7de13a35276a476420655433a.png
# /kaggle/working/predicted_masks/3c84417fda8019410b1fcf0625f608b4.png
# /kaggle/working/predicted_masks/559c7e610b1531871f2fd85a04faeeb2.png
# /kaggle/working/predicted_masks/9c7976c1182df0de51d32128c358d1fd.png
# /kaggle/working/predicted_masks/a6d9ba9d45c3dbc695325ded465efde9.png
# /kaggle/working/predicted_masks/faef7fdb2d45b21960c94b0aab4c024a.png
# /kaggle/working/predicted_masks/318ecf467d7ad048df39beb176363408.png
# /kaggle/working/predicted_masks/780fd497e1c0e9082ea2c193ac8d551c.png
# /kaggle/working/predicted_masks/e7998934d417cb2eb1ef57af2ed9fbb6.png
# /kaggle/working/predicted_masks/27738677a6b1f2c6d40b3bbba8f6c704.png
# /kaggle/working/predicted_masks/60a633a8d5b2b2b55157b7781e2c706c.png
# /kaggle/working/predicted_masks/b70dd094a7f32574d6c748c41743c6c0.png
# /kaggle/working/predicted_masks/6f67b5df7cdf3f33c3ca4d5060a633a8.png
# /kaggle/working/predicted_masks/3dd311a65d2b46d0a6085835c525af63.png
# /kaggle/working/predicted_masks/c656702fa602bb3c7abacdbd7e6afd56.png
# /kaggle/working/predicted_masks/3425b976973f13dd311a65d2b46d0a60.png
# /kaggle/working/predicted_masks/13dd311a65d2b46d0a6085835c525af6.png
# /kaggle/working/predicted_masks/8cbdf366e057db382b8564872a27301a.png
# /kaggle/working/predicted_masks/02fa602bb3c7abacdbd7e6afd56ea7bc.png
# /kaggle/working/predicted_masks/77e004e8bfb905b78a91391adc0bb223.png
# /kaggle/working/predicted_masks/d077bad31c8c5f54ffaa27a623511c38.png
# /kaggle/working/predicted_masks/a3657e4314fe384eb2ba3adfda6c1899.png
# /kaggle/working/predicted_masks/db5eb2a0e4b50889d874c68c030b9afe.png
# /kaggle/working/predicted_masks/2ed9fbb63b28163a745959c03983064a.png
# /kaggle/working/predicted_masks/4baddc22268d4b4ef4d95ceea1195799.png
# /kaggle/working/predicted_masks/3bbc04a3afe1f119f21b248d152b672a.png
# /kaggle/working/predicted_masks/f7fdb2d45b21960c94b0aab4c024a573.png
# /kaggle/working/predicted_masks/68d4b4ef4d95ceea11957998906d3694.png
# /kaggle/working/predicted_masks/391adc0bb223c4eaf3372eae567c94ea.png
# /kaggle/working/predicted_masks/fdbc3bbc04a3afe1f119f21b248d152b.png
# /kaggle/working/predicted_masks/be4d18d5401f659532897255ce2dd4ae.png
# /kaggle/working/predicted_masks/dd78294679c9cbb2a365b5574868eb60.png
# /kaggle/working/predicted_masks/cdf3f33c3ca4d5060a633a8d5b2b2b55.png
# /kaggle/working/predicted_masks/15fc656702fa602bb3c7abacdbd7e6af.png
# /kaggle/working/predicted_masks/e1e0ae936de314f2d95e6c487ffa651b.png
# /kaggle/working/predicted_masks/d3694abb47953b0e4909384b57bb6a05.png
# /kaggle/working/predicted_masks/8eb5a9a8a8d7fcc9df8e5ad89d284483.png
# /kaggle/working/predicted_masks/d6240619ebebe9e9c9d00a4262b4fe4a.png
# /kaggle/working/predicted_masks/94a7f32574d6c748c41743c6c08a1d1a.png
# /kaggle/working/predicted_masks/6ad1468996b4a9ce6d840b53a6558038.png
# /kaggle/working/predicted_masks/fe1f119f21b248d152b672ab3492fc62.png
